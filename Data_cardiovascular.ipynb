# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/data_cardiovascular_risk.csv')

# %%
df.head()
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# ...

# %%
df.describe()
# Out:
#                 id          age    education   cigsPerDay       BPMeds  \
# count  3390.000000  3390.000000  3303.000000  3368.000000  3346.000000
# mean   1694.500000    49.542183     1.970936     9.069477     0.029886
# std     978.753033     8.592878     1.019081    11.879078     0.170299
# min       0.000000    32.000000     1.000000     0.000000     0.000000
# 25%     847.250000    42.000000     1.000000     0.000000     0.000000
# 50%    1694.500000    49.000000     2.000000     0.000000     0.000000
# 75%    2541.750000    56.000000     3.000000    20.000000     0.000000
# max    3389.000000    70.000000     4.000000    70.000000     1.000000
#
#        prevalentStroke  prevalentHyp     diabetes      totChol       sysBP  \
# count      3390.000000   3390.000000  3390.000000  3352.000000  3390.00000
# mean          0.006490      0.315339     0.025664   237.074284   132.60118
# std           0.080309      0.464719     0.158153    45.247430    22.29203
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# education           87
# sex                  0
# is_smoking           0
# cigsPerDay          22
# BPMeds              44
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             38
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
df['education'].value_counts()
mu_education = df['education'].idxmax()
df['education'].replace(np.nan, mu_education, inplace=True)

# %%
df['education'].isnull().sum()
# Out:
# 0

# %%
avg_cigs = df['cigsPerDay'].mean()
avg_cigs = int(avg_cigs)

df['cigsPerDay'].replace(np.nan, avg_cigs, inplace=True)

# %%
df['cigsPerDay'].isnull().sum()
# Out:
# 0

# %%
df['BPMeds'].value_counts()
max_BPMeds = df['BPMeds'].max()
min_BPMeds = df['BPMeds'].min()
df['BPMeds'].replace(np.nan, min_BPMeds, inplace=True )

# %%
df['BPMeds'].isnull().sum()
# Out:
# 0

# %%
df['totChol'].value_counts()
df['totChol'].mean()
avg_chol = df['totChol'].mean()
avg_chol = int(avg_chol)

df['totChol'].replace(np.nan, avg_chol, inplace=True )

# %%
df['totChol'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                   0
# age                  0
# education            0
# sex                  0
# is_smoking           0
# cigsPerDay           0
# BPMeds               0
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol              0
# sysBP                0
# diaBP                0
# BMI                 14
# heartRate            1
# glucose            304
# TenYearCHD           0
# dtype: int64

# %%
df['BMI'].mean()
avg_BMI = df['BMI'].mean()
df['BMI'].replace(np.nan, avg_BMI, inplace=True )

# %%
df['BMI'].isnull().sum()
# Out:
# 0

# %%
df['heartRate'].value_counts()
avg_heartRate = df['heartRate'].mean()
avg_heartRate = int(avg_heartRate)
df['heartRate'].replace(np.nan, avg_heartRate, inplace=True )
df['glucose'].value_counts()
avg_glucose = df['glucose'].mean()
df['glucose'].replace(np.nan, avg_glucose, inplace=True )

# %%
df['heartRate'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# id                 0
# age                0
# education          0
# sex                0
# is_smoking         0
# cigsPerDay         0
# BPMeds             0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# totChol            0
# sysBP              0
# diaBP              0
# BMI                0
# heartRate          0
# glucose            0
# TenYearCHD         0
# dtype: int64

# %%
df_s_cigs = df[['sex','cigsPerDay']]
df_s_cigs.head()
grouped_df_s_cigs = df_s_cigs.groupby(['sex'],as_index=False).mean()
grouped_df_s_cigs.head()
# Out:
#   sex  cigsPerDay
# 0   F    5.645866
# 1   M   13.556237

# %%
plt.pie(grouped_df_s_cigs["cigsPerDay"], labels=grouped_df_s_cigs["sex"], autopct='%1.1f%%', shadow=True)
plt.legend(title= 'Cigarettes per Day by sex')
plt.show()

# %%
sns.boxplot(data=df, x='education', y='BMI')
# Out:
# <Axes: xlabel='education', ylabel='BMI'>

# %%
df1 = pd.get_dummies(df, columns=['sex', 'is_smoking'], drop_first=True )

# %%
df1.head()
# Out:
#    id  age  education  cigsPerDay  BPMeds  prevalentStroke  prevalentHyp  \
# 0   0   64        2.0         3.0     0.0                0             0
# 1   1   36        4.0         0.0     0.0                0             1
# 2   2   46        1.0        10.0     0.0                0             0
# 3   3   50        1.0        20.0     0.0                0             1
# 4   4   64        1.0        30.0     0.0                0             0
#
#    diabetes  totChol  sysBP  diaBP        BMI  heartRate  glucose  TenYearCHD  \
# 0         0    221.0  148.0   85.0  25.794964       90.0     80.0           1
# 1         0    212.0  168.0   98.0  29.770000       72.0     75.0           0
# 2         0    250.0  116.0   71.0  20.350000       88.0     94.0           0
# 3         0    233.0  158.0   88.0  28.260000       68.0     94.0           1
# 4         0    241.0  136.5   85.0  26.420000       70.0     77.0           0
#
#    sex_M  is_smoking_YES
# 0  False            True
# ...

# %%
df1.corr()
# Out:
#                        id       age  education  cigsPerDay    BPMeds  \
# id               1.000000  0.016759  -0.027337   -0.017199  0.007014
# age              0.016759  1.000000  -0.170614   -0.191955  0.122114
# education       -0.027337 -0.170614   1.000000    0.014146 -0.019880
# cigsPerDay      -0.017199 -0.191955   0.014146    1.000000 -0.036654
# BPMeds           0.007014  0.122114  -0.019880   -0.036654  1.000000
# prevalentStroke -0.038873  0.059038  -0.031820   -0.042053  0.116183
# prevalentHyp     0.013236  0.308826  -0.081925   -0.079086  0.256892
# diabetes         0.003690  0.107875  -0.051895   -0.049006  0.070932
# totChol         -0.019783  0.272203  -0.021317   -0.024435  0.081138
# sysBP            0.019676  0.404845  -0.132202   -0.100545  0.260384
# diaBP            0.000832  0.221896  -0.060774   -0.068550  0.198780
# BMI              0.039750  0.137645  -0.135822   -0.100707  0.087577
# heartRate        0.024691 -0.002636  -0.039395    0.066495  0.018107
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df1.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.violinplot(data=df1, x='sex_M', y='cigsPerDay')
# Out:
# <Axes: xlabel='sex_M', ylabel='cigsPerDay'>

# %%
sns.lineplot(data=df1, x='age', y='sysBP',color='r')
# Out:
# <Axes: xlabel='age', ylabel='sysBP'>

# %%
sns.lineplot(data=df1, x='sysBP', y='diaBP')
# Out:
# <Axes: xlabel='sysBP', ylabel='diaBP'>

# %%
sns.regplot(data=df1, x='sysBP', y='BMI', color='g')
# Out:
# <Axes: xlabel='sysBP', ylabel='BMI'>

# %%
df['glucose'].value_counts()
df['diabetes'].value_counts()
sns.boxplot(data=df1, x='diabetes', y='glucose')
# Out:
# <Axes: xlabel='diabetes', ylabel='glucose'>

# %%
sns.boxplot(data=df1, x='prevalentHyp', y='sysBP')
# Out:
# <Axes: xlabel='prevalentHyp', ylabel='sysBP'>

# %%
sns.boxplot(data=df1, x='diabetes', y='glucose')
sns.set_theme(style="ticks")

# %%
df2 = df1[['age','education','cigsPerDay','totChol','sysBP','diaBP','BMI','heartRate','glucose','sex_M']]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   age         3390 non-null   int64
#  1   education   3390 non-null   float64
#  2   cigsPerDay  3390 non-null   float64
#  3   totChol     3390 non-null   float64
#  4   sysBP       3390 non-null   float64
#  5   diaBP       3390 non-null   float64
#  6   BMI         3390 non-null   float64
#  7   heartRate   3390 non-null   float64
#  8   glucose     3390 non-null   float64
#  9   sex_M       3390 non-null   bool
# dtypes: bool(1), float64(8), int64(1)
# memory usage: 241.8 KB

# %%
df2
# Out:
#       age  education  cigsPerDay  totChol  sysBP  diaBP        BMI  heartRate  \
# 0      64        2.0         3.0    221.0  148.0   85.0  25.794964       90.0
# 1      36        4.0         0.0    212.0  168.0   98.0  29.770000       72.0
# 2      46        1.0        10.0    250.0  116.0   71.0  20.350000       88.0
# 3      50        1.0        20.0    233.0  158.0   88.0  28.260000       68.0
# 4      64        1.0        30.0    241.0  136.5   85.0  26.420000       70.0
# ...   ...        ...         ...      ...    ...    ...        ...        ...
# 3385   60        1.0         0.0    261.0  123.5   79.0  29.280000       70.0
# 3386   46        1.0         0.0    199.0  102.0   56.0  21.960000       80.0
# 3387   44        3.0         3.0    352.0  164.0  119.0  28.920000       73.0
# 3388   60        1.0         0.0    191.0  167.0  105.0  23.010000       80.0
# 3389   54        3.0         0.0    288.0  124.0   77.0  29.880000       79.0
#
#       glucose  sex_M
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df1.corr(), annot=True)
# Out:
# <Axes: >

# %%
df2 = df1.drop(['is_smoking_YES','heartRate', 'BMI','totChol', 'prevalentStroke','BPMeds', 'cigsPerDay', 'education', 'id'], axis=1)

# %%
df2.head()
# Out:
#    age  prevalentHyp  diabetes  sysBP  diaBP  glucose  TenYearCHD  sex_M
# 0   64             0         0  148.0   85.0     80.0           1  False
# 1   36             1         0  168.0   98.0     75.0           0   True
# 2   46             0         0  116.0   71.0     94.0           0  False
# 3   50             1         0  158.0   88.0     94.0           1   True
# 4   64             0         0  136.5   85.0     77.0           0  False

# %%
df['sysBP'].value_counts()
df2['sysBP'] = df2['sysBP']/df2['sysBP'].max()
df2['age'] = df2['age']/df2['age'].max()
df2['diaBP'] = df2['diaBP']/df2['diaBP'].max()
df2['glucose'] = df2['glucose']/df2['glucose'].max()

# %%
y = df2['TenYearCHD']
x = df2.drop(['TenYearCHD'], axis=1)

# %%
x.head()
# Out:
#         age  prevalentHyp  diabetes     sysBP     diaBP   glucose  sex_M
# 0  0.914286             0         0  0.501695  0.596491  0.203046  False
# 1  0.514286             1         0  0.569492  0.687719  0.190355   True
# 2  0.657143             0         0  0.393220  0.498246  0.238579  False
# 3  0.714286             1         0  0.535593  0.617544  0.238579   True
# 4  0.914286             0         0  0.462712  0.596491  0.195431  False

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: TenYearCHD, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, random_state=42, test_size=0.3)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[-1.22599465, -0.69240626, -0.16514456, ...,  0.79737989,
#         -0.48013232, -0.89620951],
#        [ 1.21819608,  1.44423881, -0.16514456, ...,  2.9384277 ,
#         -1.00074462, -0.89620951],
#        [ 0.6362459 ,  1.44423881, -0.16514456, ...,  2.09880111,
#         -0.69705411,  1.11581052],
#        ...,
#        [ 0.51985587, -0.69240626, -0.16514456, ..., -0.50404132,
#         -0.34997925, -0.89620951],
#        [-0.76043451, -0.69240626, -0.16514456, ..., -1.09177994,
#          0.12724869, -0.89620951],
#        [-1.22599465,  1.44423881, -0.16514456, ...,  1.55304382,
#          0.25740177, -0.89620951]])

# %%
x_test
# Out:
# array([[ 1.68375622,  1.44423881,  6.05530071, ...,  0.58747324,
#          3.9450722 , -0.89620951],
#        [-1.57516476,  1.44423881, -0.16514456, ...,  0.96530521,
#          0.12724869,  1.11581052],
#        [ 1.33458611, -0.69240626, -0.16514456, ..., -1.42763057,
#          0.60447663,  1.11581052],
#        ...,
#        [-0.41126441, -0.69240626, -0.16514456, ..., -0.7559293 ,
#         -0.26321053, -0.89620951],
#        [ 1.68375622, -0.69240626, -0.16514456, ..., -1.84744387,
#         -0.04628874,  1.11581052],
#        [ 1.21819608, -0.69240626, -0.16514456, ..., -0.336116  ,
#          0.90816714, -0.89620951]])

# %%
log = LogisticRegression()
model = log.fit(x_train, y_train)
model.score(x_test, y_test)
# Out:
# 0.8593903638151426

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[862   6]
#  [137  12]]
# 0.8593903638151426

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 0.5, 0.5])

ax.bar(y_test, y_pred, label = 'prediction', color = 'blue')
ax.set_title('Analysis')
ax.legend()

# %%
print([[y_test,y_pred]])
# Out:
# [[134     0
# 1764    0
# 2465    0
# 1987    0
# 1295    0
#        ..
# 3035    1
# 2858    0
# 994     0
# 464     0
# 3385    0
# Name: TenYearCHD, Length: 1017, dtype: int64, array([0, 0, 0, ..., 0, 0, 0])]]
